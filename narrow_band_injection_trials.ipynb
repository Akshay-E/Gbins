# %%
import os
os.environ['SETIGEN_ENABLE_GPU'] = '1'
os.environ['CUDA_VISIBLE_DEVICES'] = '3'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

import numpy as np
from astropy import units as u
import blimpy as bl

import setigen as stg
# Out:
# bshuf filter already loaded, skip it.
# zfp filter already loaded, skip it.

# %% [markdown]
# # Raw File Generation

# %%
sample_rate = 3e9
num_taps = 8
num_branches = 1024

chan_bw = sample_rate / num_branches

# %% [markdown]
# **num_taps (int, optional) – Number of PFB taps**<br>
# **num_branches (int, optional) – Number of PFB branches. Note that this results in num_branches / 2 coarse channels.**<br>
# num_branches is the FFT length for the real FFT, so that there are a resultant num_branches / 2 coarse channels possible to record.
#
# fch1 to fch1 +/- sample_rate / 2

# %%
antenna = stg.voltage.Antenna(sample_rate=sample_rate, 
                              fch1=6*u.GHz,
                              ascending=True,
                              num_pols=1)

# %%
antenna.streams

# %% [markdown]
# **ascending : Default is True, for which fch1 is the minimum frequency.**

# %%
antenna.x.add_noise(v_mean=0, 
                    v_std=1)

# antenna.y.add_noise(v_mean=0, 
#                     v_std=1)

# %%
'''print(antenna.get_samples(5))
#print(antenna.x.get_samples(5))
#print(antenna.y.get_samples(5))
'''
# Out:
# 'print(antenna.get_samples(5))\n#print(antenna.x.get_samples(5))\n#print(antenna.y.get_samples(5))\n'

# %%
antenna.x.add_constant_signal(f_start=6002.2e6, 
                              drift_rate=-2*u.Hz/u.s, 
                              level=0.2)

# antenna.y.add_constant_signal(f_start=6002.2e6, 
#                               drift_rate=-2*u.Hz/u.s, 
#                               level=0.2,
#                               phase=np.pi/2)

# %%
digitizer = stg.voltage.RealQuantizer(target_fwhm=32,
                                      num_bits=8)

filterbank = stg.voltage.PolyphaseFilterbank(num_taps=num_taps, 
                                             num_branches=num_branches)

requantizer = stg.voltage.ComplexQuantizer(target_fwhm=32,
                                           num_bits=8)

rvb = stg.voltage.RawVoltageBackend(antenna,
                                    digitizer=digitizer,
                                    filterbank=filterbank,
                                    requantizer=requantizer,
                                    start_chan=0,
                                    num_chans=64,
                                    block_size=134217728,
                                    blocks_per_file=128,
                                    num_subblocks=128)

# %% [markdown]
# num_subblocks:  Number of partitions per block, used for computation. <br>
# 32: 80000
# 128: 2400MB<br>
#
# If `num_subblocks`=1, one block's worth of data will be passed through the pipeline and recorded at once.

# %% [markdown]
# assert self.block_size % int(self.num_antennas * self.num_chans * self.num_taps * self.bytes_per_sample) == 0
#
# rvb.block_size % int(rvb.num_antennas * rvb.num_chans * rvb.num_taps * rvb.bytes_per_sample) == 0

# %%
print(rvb.num_antennas , rvb.num_chans , rvb.num_taps , rvb.bytes_per_sample)
# Out:
# 1 64 8 2

# %%
filterbank.

# %%
rvb.record(output_file_stem='syn_2',
           num_blocks=2, 
           length_mode='num_blocks',
           header_dict={'HELLO': 'test_value',
                        'TELESCOP': 'GBT'},
           verbose=False)
# Out:
# Blocks:   0%|                                                                                              | 0/2 [00:00<?, ?it/s]
#   0%|                                                                                                    | 0/128 [00:00<?, ?it/s]
# Subblocks:   0%|                                                                                         | 0/128 [00:00<?, ?it/s]
# Subblocks:   1%|▋                                                                                | 1/128 [00:00<00:18,  6.97it/s]
# Subblocks:   3%|██▌                                                                              | 4/128 [00:00<00:06, 17.84it/s]
# Subblocks:  47%|█████████████████████████████████████▌                                          | 60/128 [00:03<00:03, 19.66it/s]
# Subblocks:  49%|███████████████████████████████████████▍                                        | 63/128 [00:03<00:03, 17.88it/s]
# Subblocks:  51%|████████████████████████████████████████▋                                       | 65/128 [00:03<00:03, 15.97it/s]
# Subblocks:  53%|██████████████████████████████████████████▌                                     | 68/128 [00:03<00:03, 17.64it/s]
# Subblocks:  55%|████████████████████████████████████████████▍                                   | 71/128 [00:03<00:02, 20.08it/s]
# Subblocks:  58%|██████████████████████████████████████████████▎                                 | 74/128 [00:03<00:02, 22.18it/s]
# Subblocks:  60%|████████████████████████████████████████████████▏                               | 77/128 [00:03<00:02, 23.80it/s]
# Subblocks:  62%|██████████████████████████████████████████████████                              | 80/128 [00:04<00:01, 24.94it/s]
# Subblocks:  65%|███████████████████████████████████████████████████▉                            | 83/128 [00:04<00:01, 23.59it/s]
# Subblocks:  67%|█████████████████████████████████████████████████████▊                          | 86/128 [00:04<00:01, 24.95it/s]
# Subblocks:  70%|███████████████████████████████████████████████████████▋                        | 89/128 [00:04<00:01, 25.87it/s]
# Subblocks:  72%|█████████████████████████████████████████████████████████▌                      | 92/128 [00:04<00:01, 26.52it/s]
# Subblocks:  74%|███████████████████████████████████████████████████████████▍                    | 95/128 [00:04<00:01, 27.05it/s]
# Subblocks:  77%|█████████████████████████████████████████████████████████████▎                  | 98/128 [00:04<00:01, 25.09it/s]
# Subblocks:  79%|██████████████████████████████████████████████████████████████▎                | 101/128 [00:04<00:01, 25.99it/s]
# Subblocks:  81%|████████████████████████████████████████████████████████████████▏              | 104/128 [00:04<00:00, 26.64it/s]
# Subblocks:  84%|██████████████████████████████████████████████████████████████████             | 107/128 [00:05<00:00, 27.07it/s]
# Subblocks:  86%|███████████████████████████████████████████████████████████████████▉           | 110/128 [00:05<00:00, 27.44it/s]
# Subblocks:  88%|█████████████████████████████████████████████████████████████████████▋         | 113/128 [00:05<00:00, 26.99it/s]
# Subblocks:  91%|███████████████████████████████████████████████████████████████████████▌       | 116/128 [00:05<00:00, 21.68it/s]
# Subblocks:  93%|█████████████████████████████████████████████████████████████████████████▍     | 119/128 [00:05<00:00, 19.25it/s]
# Subblocks:  95%|███████████████████████████████████████████████████████████████████████████▎   | 122/128 [00:05<00:00, 17.83it/s]
# Subblocks:  97%|████████████████████████████████████████████████████████████████████████████▌  | 124/128 [00:05<00:00, 16.99it/s]
# Subblocks:  99%|██████████████████████████████████████████████████████████████████████████████▍| 127/128 [00:06<00:00, 18.83it/s]
# Blocks: 100%|██████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:14<00:00,  7.27s/it]

# %%
# !rawspec -f 1024 -t 4 -d . syn_2
# Out:
# working stem: syn_2
# opening file: syn_2.0000.raw
# opening file: syn_2.0001.raw [No such file or directory]
# output product 0: 512 spectra

# %% [markdown]
# rawspec reads GUPPI RAW files and produces integrated power spectra. Up to 4 different output products with various channelization/integration combinations can be created at one time. Output products can either be total power (aka Stokes I) or full cross polarization spectra. Currently, rawspec outputs to SIGPROC Filterbank files, see http://sigproc.sourceforge.net. It can also output the spectral data as UDP packets to a remote receiver. Each such UDP packet is a small, self-contained Filterbank "file".
#
# -d, --dest=DEST        Destination directory or host:port<br>
#   -f, --ffts=N1[,N2...]  FFT lengths [1048576, 8, 1024]<br>
#   -g, --GPU=IDX          Select GPU device to use [0]<br>
#   -H, --hdrs             Save headers to separate file<br>
#   -n, --nchan=N          Number of coarse channels to process [all]<br>
#   -o, --outidx=N         First index number for output files [0]<br>
#   -p  --pols={1|4}[,...] Number of output polarizations [1]<br>
#                          1=total power, 4=cross pols, -4=full stokes<br>
#   -r, --rate=GBPS        Desired net data rate in Gbps [6.0]<br>
#   -s, --schan=C          First coarse channel to process [0]<br>
#   -t, --ints=N1[,N2...]  Spectra to integrate [51, 128, 3072]<br>

# %%
# %matplotlib inline
wf = bl.Waterfall('syn_1.rawspec.0000.fil',
                  f_start=6001.5,
                  f_stop=6003.0)

plt.figure(figsize=(10, 6))
wf.plot_waterfall()
plt.show()

# %%
len(wf.data)
# Out:
# 128

# %%
type(wf.data)
# Viewing data in dB
x = stg.db(np.sum(wf.data[:, 0, :], axis=0))

plt.figure(figsize=(8, 6))
plt.plot(x)
plt.xlabel('Frequency bins')
plt.ylabel('Integrated Power (dB)')
plt.show()

# %% [markdown]
# # Detecting signals from existing guppi raw

# %%
start_chan = 0
input_file_stem = 'syn_1'

raw_params = stg.voltage.get_raw_params(input_file_stem=input_file_stem,
                                        start_chan=start_chan)

antenna = stg.voltage.Antenna(sample_rate=sample_rate,
                              **raw_params)

# %%
start_chan = 0
input_file_stem = 'syn_1'

raw_params = stg.voltage.get_raw_params(input_file_stem=input_file_stem,
                                        start_chan=start_chan)

antenna = stg.voltage.Antenna(sample_rate=2*raw_params['chan_bw'],
                              **raw_params)

# %%
raw_params
# Out:
# {'num_bits': 8,
#  'chan_bw': 2929687.5,
#  'ascending': True,
#  'num_pols': 1,
#  'block_size': 134217728,
#  'obs_length': 0.3579139413333333,
#  'tbin': 3.41333333333333e-07,
#  'num_antennas': 1,
#  'num_chans': 64,
#  'center_freq': 6092285156.25,
#  'fch1': 6000000000.0}

# %%
filterbank = stg.voltage.PolyphaseFilterbank(num_taps=num_taps, 
                                             num_branches=num_branches)

rvb = stg.voltage.RawVoltageBackend.from_data(input_file_stem=input_file_stem,
                                              antenna_source=antenna,
                                              filterbank=filterbank,
                                              start_chan=start_chan,
                                              num_subblocks=128)

# %% [markdown]
# If the signal is non-drifting, in general the spectral response will go as 1/sinc^2(x), where x is the fractional error off of the center of the spectral bin. To calculate the corresponding amount to adjust signal_level, you can use stg.voltage.get_leakage_factor(f_start, raw_voltage_backend, fftlength). This technically calculates 1/sinc(x), which is inherently squared naturally along with the cosine signal amplitude during fine channelization.<br>
#
# level = stream.get_total_noise_std() * leakage_factor * signal_level<br>
#
#  filterbank data products are powers, the final signal strength goes as the square of the initial amplitude (e.g. level). Then, there are scaling factors due to the rFFT in the polyphase filterbank and the FFT in the fine channelization step. If there is a time integration, that must be accounted for in the initial amplitude. Most of these effects are calculated using stg.voltage.get_level:

# %%
fftlength = 1024
signal_level = stg.voltage.get_level(snr=15,
                                     raw_voltage_backend=rvb,
                                     fftlength=fftlength,
                                     num_blocks=1,
                                     length_mode='num_blocks')

for f_start in np.linspace(6003.1e6, 6003.8e6, 5):
    leakage_factor = stg.voltage.get_leakage_factor(f_start, rvb, fftlength)
    print(f'{f_start/1e6:.4f} MHz leakage factor: {leakage_factor:.3f}')
    
    for stream in antenna.streams:
        # There's actually no noise present, but we set levels assuming a background noise_std of 1
        level = 1 * leakage_factor * signal_level
        stream.add_constant_signal(f_start=f_start, 
                                   drift_rate=0*u.Hz/u.s, 
                                   level=level)

rvb.record(output_file_stem='syn_1_from_data_sample_rate_calculated',
           num_blocks=1, 
           length_mode='num_blocks',
           header_dict={'TELESCOP': 'GBT'},
           digitize=False,
           verbose=False)

# !rawspec -f 1024 -t 4 -d . syn_1_from_data_sample_rate_calculated
# Out:
# 6003.1000 MHz leakage factor: 1.304
# 6003.2750 MHz leakage factor: 1.010
# 6003.4500 MHz leakage factor: 1.434
# 6003.6250 MHz leakage factor: 1.001
# 6003.8000 MHz leakage factor: 1.536
# Blocks:   0%|                                                                                              | 0/1 [00:00<?, ?it/s]
#   0%|                                                                                                    | 0/128 [00:00<?, ?it/s]
# Subblocks:   0%|                                                                                         | 0/128 [00:00<?, ?it/s]
# Subblocks:   1%|▋                                                                                | 1/128 [00:00<00:27,  4.54it/s]
# Subblocks:   2%|█▎                                                                               | 2/128 [00:00<00:20,  6.14it/s]
# Subblocks:   2%|█▉                                                                               | 3/128 [00:00<00:17,  6.97it/s]
# Subblocks:   3%|██▌                                                                              | 4/128 [00:00<00:16,  7.63it/s]
# Subblocks:   4%|███▏                                                                             | 5/128 [00:00<00:15,  8.15it/s]
# Subblocks:   5%|███▊                                                                             | 6/128 [00:00<00:14,  8.49it/s]
# Subblocks:   5%|████▍                                                                            | 7/128 [00:00<00:13,  8.72it/s]
# Subblocks:   6%|█████                                                                            | 8/128 [00:01<00:13,  8.90it/s]
# Subblocks:   7%|█████▋                                                                           | 9/128 [00:01<00:13,  9.04it/s]
# Subblocks:   8%|██████▎                                                                         | 10/128 [00:01<00:12,  9.13it/s]
# Subblocks:   9%|██████▉                                                                         | 11/128 [00:01<00:12,  9.20it/s]
# Subblocks:   9%|███████▌                                                                        | 12/128 [00:01<00:12,  9.26it/s]
# Subblocks:  10%|████████▏                                                                       | 13/128 [00:01<00:12,  9.31it/s]
# Subblocks:  11%|████████▊                                                                       | 14/128 [00:01<00:12,  9.32it/s]
# Subblocks:  12%|█████████▍                                                                      | 15/128 [00:01<00:12,  9.27it/s]
# Subblocks:  12%|██████████                                                                      | 16/128 [00:01<00:12,  9.22it/s]
# Subblocks:  13%|██████████▋                                                                     | 17/128 [00:02<00:13,  8.47it/s]
# Subblocks:  14%|███████████▎                                                                    | 18/128 [00:02<00:12,  8.64it/s]
# Subblocks:  15%|███████████▉                                                                    | 19/128 [00:02<00:12,  8.81it/s]
# Subblocks:  16%|████████████▌                                                                   | 20/128 [00:02<00:12,  8.99it/s]
# Subblocks:  16%|█████████████▏                                                                  | 21/128 [00:02<00:11,  9.10it/s]
# Subblocks:  17%|█████████████▊                                                                  | 22/128 [00:02<00:11,  9.17it/s]
# Subblocks:  91%|████████████████████████████████████████████████████████████████████████▏      | 117/128 [00:14<00:01,  8.74it/s]
# Subblocks:  92%|████████████████████████████████████████████████████████████████████████▊      | 118/128 [00:14<00:01,  8.76it/s]
# Subblocks:  93%|█████████████████████████████████████████████████████████████████████████▍     | 119/128 [00:14<00:01,  8.77it/s]
# Subblocks:  94%|██████████████████████████████████████████████████████████████████████████     | 120/128 [00:14<00:00,  8.78it/s]
# Subblocks:  95%|██████████████████████████████████████████████████████████████████████████▋    | 121/128 [00:14<00:00,  8.72it/s]
# Subblocks:  95%|███████████████████████████████████████████████████████████████████████████▎   | 122/128 [00:14<00:00,  8.66it/s]
# Subblocks:  96%|███████████████████████████████████████████████████████████████████████████▉   | 123/128 [00:14<00:00,  8.68it/s]
# Subblocks:  97%|████████████████████████████████████████████████████████████████████████████▌  | 124/128 [00:14<00:00,  8.67it/s]
# Subblocks:  98%|█████████████████████████████████████████████████████████████████████████████▏ | 125/128 [00:14<00:00,  8.68it/s]
# Subblocks:  98%|█████████████████████████████████████████████████████████████████████████████▊ | 126/128 [00:15<00:00,  8.61it/s]
# Subblocks:  99%|██████████████████████████████████████████████████████████████████████████████▍| 127/128 [00:15<00:00,  8.63it/s]
# Subblocks: 100%|███████████████████████████████████████████████████████████████████████████████| 128/128 [00:15<00:00,  8.69it/s]
# Blocks: 100%|██████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:43<00:00, 43.30s/it]
# working stem: syn_1_from_data_sample_rate_calculated
# opening file: syn_1_from_data_sample_rate_calculated.0000.raw
# opening file: syn_1_from_data_sample_rate_calculated.0001.raw [No such file or directory]
# output product 0: 256 spectra

# %%
# %matplotlib inline 
wf = bl.Waterfall(#'syn_1_from_data_sample_rate_calculated.rawspec.0000.fil',
                  'syn_1_from_data.rawspec.0000.fil',
                    f_start=6003.0,
                  f_stop=6004.0)

plt.figure(figsize=(10, 6))
wf.plot_waterfall()
plt.show()

frame = stg.Frame(wf)

spectrum = stg.integrate(frame, normalize=True)

plt.figure(figsize=(8, 6))
plt.plot(spectrum)
plt.xlabel('Frequency bins')
plt.ylabel('SNR')
plt.show()

# %%
# %matplotlib inline 
wf = bl.Waterfall('syn_1_from_data_sample_rate_calculated.rawspec.0000.fil',
                  #'syn_1_from_data.rawspec.0000.fil',f_start=6003.0,
                  f_start=6003.0,
                  f_stop=6004.0)

plt.figure(figsize=(10, 6))
wf.plot_waterfall()
plt.show()

frame = stg.Frame(wf)

spectrum = stg.integrate(frame, normalize=True)

plt.figure(figsize=(8, 6))
plt.plot(spectrum)
plt.xlabel('Frequency bins')
plt.ylabel('SNR')
plt.show()

# %% [markdown]
# ### turbo_SETI

# %%
import os
import glob
import time 
# 3rd party packages
import pylab as plt
from blimpy import Waterfall
import turbo_seti.find_doppler.seti_event as turbo
import turbo_seti.find_event as find
from turbo_seti.find_doppler.find_doppler import FindDoppler
from turbo_seti.find_event.find_event_pipeline import find_event_pipeline
from turbo_seti.find_event.plot_event_pipeline import plot_event_pipeline

# %%
data_directory='/home/eakshay/setigen/' #syn_1_from_data.rawspec.0000.fil
op_directory='/home/eakshay/setigen/turbo/'

# %%
#os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"
# !fil2h5 syn_1_from_data.rawspec.0000.fil
# Out:
# bshuf filter already loaded, skip it.
# zfp filter already loaded, skip it.
# blimpy.waterfall INFO     Detecting intermediate frequency and time resolution data.
# blimpy.waterfall INFO     __write_to_hdf5_heavy: For ./syn_1_from_data.rawspec.0000.h5, chunk_dim=(10, 1, 65536), blob_dim=(256, 1, 65536), n_blobs=1
# blimpy.waterfall ERROR    __write_to_hdf5_heavy: Writing the output HDF5 file ./syn_1_from_data.rawspec.0000.h5 failed!
# OSError(37, "Unable to create file (unable to lock file, errno = 37, error message = 'No locks available')")
# blimpy.waterfall INFO     __write_to_hdf5_heavy: Removal of partial HDF5 file ./syn_1_from_data.rawspec.0000.h5 succeeded.

# %%
h5_list = (glob.glob(os.path.join(data_directory,'*.fil')))
print(h5_list)
#print(len(h5_list))

h5_list_path = os.path.join(op_directory,'h5_files.lst')
print(h5_list_path)

with open(h5_list_path, 'w') as f:
    for h in h5_list:
        f.write(h + '\n')
        
with open(h5_list_path, 'r') as f:
    print(f.read())
# Out:
# ['/home/eakshay/setigen/syn_1.rawspec.0000.fil', '/home/eakshay/setigen/syn_2.rawspec.0000.fil', '/home/eakshay/setigen/syn_1_from_data.rawspec.0000.fil']
# /home/eakshay/setigen/turbo/h5_files.lst
# /home/eakshay/setigen/syn_1.rawspec.0000.fil
# /home/eakshay/setigen/syn_2.rawspec.0000.fil
# /home/eakshay/setigen/syn_1_from_data.rawspec.0000.fil

# %%
for file in h5_list:
    doppler = FindDoppler(file,
                      max_drift = 3, # Max drift rate = 4 Hz/second
                      snr = 10,      # Minimum signal to noise ratio = 10:1
                      out_dir = op_directory # This is where the turboSETI output files will be stored.
                     )
    doppler.search()
# Out:
# turbo_seti version 2.1.18
# blimpy version 2.0.32
# h5py version 3.6.0
#
# data_handler    INFO     Filterbank file detected. Attempting to create .h5 file in current directory...
# blimpy.waterfall INFO     Detecting intermediate frequency and time resolution data.
# blimpy.waterfall INFO     __write_to_hdf5_heavy: For /home/eakshay/setigen/turbo/syn_1.rawspec.0000.h5, chunk_dim=(10, 1, 65536), blob_dim=(256, 1, 65536), n_blobs=1
# blimpy.waterfall ERROR    __write_to_hdf5_heavy: Writing the output HDF5 file /home/eakshay/setigen/turbo/syn_1.rawspec.0000.h5 failed!
# OSError(37, "Unable to create file (unable to lock file, errno = 37, error message = 'No locks available')")
# blimpy.waterfall INFO     __write_to_hdf5_heavy: Removal of partial HDF5 file /home/eakshay/setigen/turbo/syn_1.rawspec.0000.h5 succeeded.
# root            ERROR    Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# Traceback (most recent call last):
#   File "/home/eakshay/.local/lib/python3.7/site-packages/blimpy/io/hdf_writer.py", line 66, in __write_to_hdf5_heavy
#     with h5py.File(filename_out, 'w') as h5:
#   File "/home/eakshay/.local/lib/python3.7/site-packages/h5py/_hl/files.py", line 507, in __init__
#     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#   File "/home/eakshay/.local/lib/python3.7/site-packages/h5py/_hl/files.py", line 226, in make_fid
#     fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#   File "h5py/_objects.pyx", line 54, in h5py._objects.with_phil.wrapper
#   File "h5py/_objects.pyx", line 55, in h5py._objects.with_phil.wrapper
#   File "h5py/h5f.pyx", line 126, in h5py.h5f.create
# OSError: [Errno 37] Unable to create file (unable to lock file, errno = 37, error message = 'No locks available')
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/eakshay/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3457, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_3433508/2732350970.py", line 5, in <module>
#     out_dir = op_directory # This is where the turboSETI output files will be stored.
#   File "/home/eakshay/.local/lib/python3.7/site-packages/turbo_seti/find_doppler/find_doppler.py", line 126, in __init__
#     kernels=self.kernels)
#   File "/home/eakshay/.local/lib/python3.7/site-packages/turbo_seti/find_doppler/data_handler.py", line 69, in __init__
#     self.__make_h5_file()
#   File "/home/eakshay/.local/lib/python3.7/site-packages/turbo_seti/find_doppler/data_handler.py", line 116, in __make_h5_file
#     write_to_h5(wf, h5_path)
#   File "/home/eakshay/.local/lib/python3.7/site-packages/blimpy/io/hdf_writer.py", line 184, in __write_to_hdf5_heavy
#     sys.exit(86)
# SystemExit: 86
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/eakshay/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/eakshay/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/home/eakshay/.local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/eakshay/.conda/envs/find_ET/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
# AttributeError: 'tuple' object has no attribute 'tb_frame'
# root            INFO
# Unfortunately, your original traceback can not be constructed.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/blimpy/io/hdf_writer.py in __write_to_hdf5_heavy(wf, filename_out, f_scrunch, *args, **kwargs)
#      65     try:
# ---> 66         with h5py.File(filename_out, 'w') as h5:
#      67
#
# ~/.local/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, **kwds)
#     506                                  fs_page_size=fs_page_size)
# --> 507                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     508
#
# ~/.local/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     225     elif mode == 'w':
# --> 226         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     227     elif mode == 'a':
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: [Errno 37] Unable to create file (unable to lock file, errno = 37, error message = 'No locks available')
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipykernel_3433508/2732350970.py in <module>
#       4                       snr = 10,      # Minimum signal to noise ratio = 10:1
# ----> 5                       out_dir = op_directory # This is where the turboSETI output files will be stored.
#       6                      )
#
# ~/.local/lib/python3.7/site-packages/turbo_seti/find_doppler/find_doppler.py in __init__(self, datafile, max_drift, min_drift, snr, out_dir, coarse_chans, obs_info, flagging, n_coarse_chan, kernels, gpu_backend, gpu_id, precision, append_output, log_level_int, blank_dc)
#     125                                       gpu_id=gpu_id,
# --> 126                                       kernels=self.kernels)
#     127
#
# ~/.local/lib/python3.7/site-packages/turbo_seti/find_doppler/data_handler.py in __init__(self, filename, out_dir, n_coarse_chan, coarse_chans, kernels, gpu_backend, precision, gpu_id)
#      68                 logger.info("Filterbank file detected. Attempting to create .h5 file in current directory...")
# ---> 69                 self.__make_h5_file()
#      70
#
# ~/.local/lib/python3.7/site-packages/turbo_seti/find_doppler/data_handler.py in __make_h5_file(self)
#     115             pass
# --> 116         write_to_h5(wf, h5_path)
#     117         self.filename = h5_path
#
# ~/.local/lib/python3.7/site-packages/blimpy/io/hdf_writer.py in __write_to_hdf5_heavy(wf, filename_out, f_scrunch, *args, **kwargs)
#     183                                .format(filename_out))
# --> 184             sys.exit(86)
#     185         except Exception as ex2:
#
# SystemExit: 86
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2069                            'the full traceback.\n']
#    2070                     stb.extend(self.InteractiveTB.get_exception_only(etype,
# -> 2071                                                                      value))
#    2072                 else:
#    2073                     try:
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in get_exception_only(self, etype, value)
#     752         value : exception value
#     753         """
# --> 754         return ListTB.structured_traceback(self, etype, value)
#     755
#     756     def show_exception_only(self, etype, evalue):
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     631                     chained_exceptions_tb_offset, context)
#     632                 + chained_exception_message
# --> 633                 + out_list)
#     634
#     635         return out_list
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/.local/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
import numpy as np
import h5py

d1 = np.random.random(size = (1000,20))
d2 = np.random.random(size = (1000,200))

hf = h5py.File('data.h5', 'w')
hf.create_dataset('dataset_1', data=d1)
hf.create_dataset('dataset_2', data=d2)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_3433508/261957210.py in <module>
#       5 d2 = np.random.random(size = (1000,200))
#       6
# ----> 7 hf = h5py.File('data.h5', 'w')
#       8 hf.create_dataset('dataset_1', data=d1)
#       9 hf.create_dataset('dataset_2', data=d2)
#
# ~/.local/lib/python3.7/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, **kwds)
#     505                                  fs_persist=fs_persist, fs_threshold=fs_threshold,
#     506                                  fs_page_size=fs_page_size)
# --> 507                 fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     508
#     509             if isinstance(libver, tuple):
#
# ~/.local/lib/python3.7/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     224         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     225     elif mode == 'w':
# --> 226         fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     227     elif mode == 'a':
#     228         # Open in append mode (read/write).
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.create()
#
# OSError: [Errno 37] Unable to create file (unable to lock file, errno = 37, error message = 'No locks available')

# %% [markdown]
# # backend

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

try:
    import cupy as xp
except ImportError:
    import numpy as xp
import numpy as np

from astropy import units as u
import blimpy as bl

import setigen as stg

def get_numpy(v):
    try:
        return xp.asnumpy(v)
    except AttributeError:
        return v
    
def db(x):
    """ Convert linear value to dB value """
    return 10*np.log10(x)

# %%
antenna = stg.voltage.Antenna(sample_rate=sample_rate, 
                              fch1=0*u.GHz,
                              ascending=True,
                              num_pols=1)

antenna.x.add_noise(v_mean=0, 
                    v_std=1)

v = antenna.x.get_samples(2000)
    
plt.figure(figsize=(10, 5))
plt.plot(get_numpy(v))
plt.xlabel('Sample')
plt.ylabel('V')
plt.show()

# %%
antenna.x.add_constant_signal(f_start=8e6, 
                              drift_rate=-2*u.Hz/u.s, 
                              level=0.5)
antenna.x.add_constant_signal(f_start=8.1e6, 
                              drift_rate=-4*u.Hz/u.s, 
                              level=0.2)

v = get_numpy(antenna.x.get_samples(2000))
    
plt.figure(figsize=(10, 5))
plt.plot(get_numpy(v))
plt.xlabel('Sample')
plt.ylabel('V')
plt.show()

# %% [markdown]
# # Custom signal

# %%
sample_rate = 3e9
num_taps = 8
num_branches = 1024

chan_bw = sample_rate / num_branches

digitizer = stg.voltage.RealQuantizer(target_fwhm=32,
                                      num_bits=8)

filterbank = stg.voltage.PolyphaseFilterbank(num_taps=num_taps, 
                                             num_branches=num_branches)

requantizer = stg.voltage.ComplexQuantizer(target_fwhm=32,
                                           num_bits=8)

# %%
antenna = stg.voltage.Antenna(sample_rate=sample_rate, 
                              fch1=6*u.GHz,
                              ascending=True,
                              num_pols=1)

# %%
antenna.x.add_noise(0, 1)

# %% [markdown]
# ## Adding quadratic signal

# %%
try:
    from cusignal import chirp
except ImportError:
    from scipy.signal import chirp

def my_signal(ts):
    return 0.004 * chirp(t=ts,
                         f0=6002.2e6,
                         t1=rvb.time_per_block,
                         f1=6002.3e6,
                         method='quadratic')

# def my_signal_2(ts):
#     return 0.004 * chirp(t=ts,
#                          f0=6002.4e6,
#                          t1=rvb.time_per_block,
#                          f1=6002.3e6,
#                          method='logarithmic')

# def my_signal_3(ts):
#     return 0.004 * chirp(t=ts,
#                          f0=6002.6e6,
#                          t1=rvb.time_per_block,
#                          f1=6002.3e6,
#                          method='hyperbolic')

antenna.x.add_signal(my_signal)
#antenna.x.add_signal(my_signal_2)
#antenna.x.add_signal(my_signal_3)
antenna.x.add_constant_signal(f_start=6002.0e6, drift_rate=-2*u.Hz/u.s, level=0.2)

# %% [markdown]
# There are two modes to record, num_blocks and obs_length. The former allows you to specify how many data blocks to record, as defined by the RAW format, and the latter computes the number of required blocks from the desired observation length (in seconds). The header_dict parameter allows for overwriting existing header values / adding additional keywords. For example, TurboSETI requires the TELESCOP parameter to be set to "GBT" to run on certain types of RAW files, so you can overwrite this parameter using header_dict.
#
# raw_file_stem is the path + prefix for your saved GUPPI RAW file.

# %%
rvb = stg.voltage.RawVoltageBackend(antenna,
                                    digitizer=digitizer,
                                    filterbank=filterbank,
                                    requantizer=requantizer,
                                    start_chan=0,
                                    num_chans=64,
                                    block_size=134217728,
                                    blocks_per_file=128,
                                    num_subblocks=32)

# %%
rvb.record(output_file_stem='example1_custom_signal',
           num_blocks=1, 
           length_mode='num_blocks',
           header_dict={'HELLO': 'test_value',
                        'TELESCOPE': 'GBT'},
          verbose=False
          )
# Out:
# Blocks:   0%|                                                                                                                     | 0/1 [00:00<?, ?it/s]
#   0%|                                                                                                                            | 0/32 [00:00<?, ?it/s]
# Subblocks:   0%|                                                                                                                 | 0/32 [00:00<?, ?it/s]
# Blocks:   0%|                                                                                                                     | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3433508/217000802.py in <module>
#       4            header_dict={'HELLO': 'test_value',
#       5                         'TELESCOPE': 'GBT'},
# ----> 6           verbose=False
#       7           )
#
# ~/.conda/envs/find_ET/lib/python3.7/site-packages/setigen/voltage/backend.py in record(self, output_file_stem, obs_length, num_blocks, length_mode, header_dict, digitize, verbose)
#     597                         v = self.collect_data_block(digitize=digitize,
#     598                                                     requantize=True,
# --> 599                                                     verbose=verbose)
#     600
#     601                         f.write(xp.array(v, dtype=xp.int8).tobytes())
#
# ~/.conda/envs/find_ET/lib/python3.7/site-packages/setigen/voltage/backend.py in collect_data_block(self, digitize, requantize, verbose)
#     419                 # Calculate the real voltage samples from each antenna
#     420                 t = time.time()
# --> 421                 antennas_v = self.antenna_source.get_samples(num_samples)
#     422                 self.sample_stage_t += time.time() - t
#     423
#
# ~/.conda/envs/find_ET/lib/python3.7/site-packages/setigen/voltage/antenna.py in get_samples(self, num_samples)
#     123                         self.y.get_samples(num_samples)]]
#     124         else:
# --> 125             samples = [[self.x.get_samples(num_samples)]]
#     126
#     127         self.t_start += num_samples * self.dt
#
# ~/.conda/envs/find_ET/lib/python3.7/site-packages/setigen/voltage/data_stream.py in get_samples(self, num_samples)
#     226         for signal_func in self.signal_sources:
#     227             # Ensure that the array is of the correct type
# --> 228             signal_v = xp.array(signal_func(self.ts))
#     229             # If there are complex voltages, make sure to cast self.v to complex
#     230             if not xp.iscomplexobj(self.v) and xp.iscomplexobj(signal_v):
#
# /tmp/ipykernel_3433508/781931191.py in my_signal(ts)
#       9                          t1=rvb.time_per_block,
#      10                          f1=6002.3e6,
# ---> 11                          method='quadratic')
#      12
#      13 # def my_signal_2(ts):
#
# ~/.local/lib/python3.7/site-packages/scipy/signal/waveforms.py in chirp(t, f0, t1, f1, method, phi, vertex_zero)
#     408     """
#     409     # 'phase' is computed in _chirp_phase, to make testing easier.
# --> 410     phase = _chirp_phase(t, f0, t1, f1, method, vertex_zero)
#     411     # Convert  phi to radians.
#     412     phi *= pi / 180
#
# ~/.local/lib/python3.7/site-packages/scipy/signal/waveforms.py in _chirp_phase(t, f0, t1, f1, method, vertex_zero)
#     421
#     422     """
# --> 423     t = asarray(t)
#     424     f0 = float(f0)
#     425     t1 = float(t1)
#
# ~/.local/lib/python3.7/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# cupy/core/core.pyx in cupy.core.core.ndarray.__array__()
#
# TypeError: Implicit conversion to a NumPy array is not allowed. Please use `.get()` to construct a NumPy array explicitly.

# %%
# !rawspec -f 1024 -t 16 -d example_custom_signal

# %%
wf = bl.Waterfall('example_custom_signal.rawspec.0000.fil',
                  f_start=6001.0,
                  f_stop=6003.0)

plt.figure(figsize=(10, 6))
wf.plot_waterfall()
plt.show()
